# %%
# prompt: delete the src directory

# !rm -rf runs

# %%
# prompt: unzip the landmine_detection.v1i.yolov11.zip stored in my colab session files

# !unzip /content/landmines_detection.v1i.yolov11.zip
# Out:
# Archive:  /content/landmines_detection.v1i.yolov11.zip
#    creating: landmines_detection.v1i.yolov11/
#   inflating: landmines_detection.v1i.yolov11/data.yaml
#   inflating: landmines_detection.v1i.yolov11/date_subset_.2.yaml
#   inflating: landmines_detection.v1i.yolov11/README.dataset.txt
#   inflating: landmines_detection.v1i.yolov11/README.roboflow.txt
#    creating: landmines_detection.v1i.yolov11/test/
#    creating: landmines_detection.v1i.yolov11/test/images/
#   inflating: landmines_detection.v1i.yolov11/test/images/1013_Zone_7_Mine_5cm_depth__2-0m_TemperatureInCenter__45A-C_jpg.rf.962ff20d00dc7ed3ba2eaff7225cda97.jpg
#   inflating: landmines_detection.v1i.yolov11/test/images/1060_Zone_1_Mine_1cm_depth__1-3m_TemperatureInCenter__27A-C_jpg.rf.7019d990e21986dce3fc474d306e874f.jpg
#   inflating: landmines_detection.v1i.yolov11/test/images/1061_Zone_1_Mine_1cm_depth__1-3m_TemperatureInCenter__28A-C_jpg.rf.5930d2c404d6c7e429a9abb29decd2ec.jpg
# ...

# %%
# prompt: intall ultralytics if it isnt there already

try:
  import ultralytics
except ImportError:
  # !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 19.6 MB/s eta 0:00:00
# ...

# %%
# prompt: work out what devices are available to me

import os

def get_available_devices():
  """
  Identifies and returns a list of available devices (CPU, GPU, etc.)
  """
  available_devices = []

  # Check for CUDA devices (GPUs)
  if os.system('nvidia-smi') == 0:  # Check if nvidia-smi command works
      available_devices.append("GPU")

  # Default to CPU if no GPU found
  if not available_devices:
      available_devices.append("CPU")

  return available_devices

devices = get_available_devices()
print("Available devices:", devices)
# Out:
# Available devices: ['GPU']

# %%
# prompt: wirte code to determine if the gpu is device 0 or 1,2,3 etc

import tensorflow as tf

def get_gpu_device_number():
  """
  Gets the device number of the GPU if available, otherwise returns None.
  """
  if tf.config.list_physical_devices('GPU'):
    return tf.config.list_physical_devices('GPU')[0].name.split(':')[-1]
  else:
    return None

gpu_device_number = get_gpu_device_number()
if gpu_device_number:
  print(f"GPU device number: {gpu_device_number}")
else:
  print("No GPU detected.")
# Out:
# GPU device number: 0

# %%
from ultralytics import YOLO

# Load a YOLOv5 model
model = YOLO('/content/src/models/yolo11n.pt')

# Train the model
results_subset_20 = model.train(data='/content/landmines_detection.v1i.yolov11/data_subset_2_colab.yaml',
                                epochs=50,
                                imgsz=640,
                                device = 0)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print("hellow world")
# Out:
# hellow world

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# prompt: zip the runs dir

# !zip -r /content/runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train/results.csv (deflated 60%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 31%)
#   adding: content/runs/detect/train/labels.jpg (deflated 46%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 48%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 11%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 1%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 29%)
#   adding: content/runs/detect/train/R_curve.png (deflated 17%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
# ...

# %%
# prompt: download the runs.zip file

from google.colab import files
files.download('/content/runs.zip')
